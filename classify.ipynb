# %%
import pandas as pd
data = [
    {'Station': 'Aldgate', 'Accessibility1.5': 1482.715111},
    {'Station': "St. Paul's", 'Accessibility1.5': 534.283116},
    {'Station': 'Cannon Street', 'Accessibility1.5': 524.809292},
    {'Station': 'Bank', 'Accessibility1.5': 524.093095},
    {'Station': 'Monument', 'Accessibility1.5': 493.588015},
    {'Station': 'Baker Street', 'Accessibility1.5': 441.944452},
    {'Station': 'Piccadilly Circus', 'Accessibility1.5': 431.652306},
    {'Station': 'Mansion House', 'Accessibility1.5': 426.929167},
    {'Station': 'Covent Garden', 'Accessibility1.5': 424.797389},
    {'Station': 'Barbican', 'Accessibility1.5': 406.645785},
    {'Station': 'Liverpool Street', 'Accessibility1.5': 401.272370},
    {'Station': 'Leicester Square', 'Accessibility1.5': 372.097670},
    {'Station': 'Blackfriars', 'Accessibility1.5': 361.985662},
    {'Station': 'Oxford Circus', 'Accessibility1.5': 357.072675},
    {'Station': 'Charing Cross', 'Accessibility1.5': 348.210559},
    {'Station': 'Moorgate', 'Accessibility1.5': 327.771320},
    {'Station': 'TOWER GATEWAY - DLR', 'Accessibility1.5': 327.464254},
    {'Station': 'Farringdon', 'Accessibility1.5': 327.379466},
    {'Station': 'Tottenham Court Road', 'Accessibility1.5': 303.621332},
    {'Station': 'Gloucester Road', 'Accessibility1.5': 297.810470},
    {'Station': 'Embankment', 'Accessibility1.5': 293.011056},
    {'Station': 'Waterloo', 'Accessibility1.5': 264.967224},
    {'Station': 'London Bridge', 'Accessibility1.5': 263.587671},
    {'Station': 'Tower Hill', 'Accessibility1.5': 263.064283},
    {'Station': 'Westminster', 'Accessibility1.5': 245.080401},
    {'Station': 'Temple', 'Accessibility1.5': 243.429412},
    {'Station': 'Chancery Lane', 'Accessibility1.5': 240.826470},
    {'Station': 'Goodge Street', 'Accessibility1.5': 240.170370},
    {'Station': 'Warren Street', 'Accessibility1.5': 234.690955},
    {'Station': 'Euston Square', 'Accessibility1.5': 222.314979},
    {'Station': 'Aldgate East', 'Accessibility1.5': 220.967053},
    {'Station': 'Lambeth North', 'Accessibility1.5': 220.592319},
    {'Station': 'Holborn', 'Accessibility1.5': 216.515281},
    {'Station': 'Green Park', 'Accessibility1.5': 214.332831},
    {'Station': 'Victoria', 'Accessibility1.5': 207.444375},
    {'Station': 'Russell Square', 'Accessibility1.5': 203.125696},
    {'Station': 'Euston', 'Accessibility1.5': 199.763645},
    {'Station': 'Bond Street', 'Accessibility1.5': 191.146213},
    {'Station': "King's Cross St. Pancras", 'Accessibility1.5': 190.557425},
    {'Station': 'Southwark', 'Accessibility1.5': 189.914381},
    {'Station': 'Borough', 'Accessibility1.5': 188.408406},
    {'Station': "St. James's Park", 'Accessibility1.5': 188.285142},
    {'Station': 'Shoreditch High Street', 'Accessibility1.5': 181.701100},
    {'Station': 'Old Street', 'Accessibility1.5': 167.880636},
    {'Station': 'Marble Arch', 'Accessibility1.5': 163.888456},
    {'Station': 'Great Portland Street', 'Accessibility1.5': 163.312262},
    {'Station': 'Knightsbridge', 'Accessibility1.5': 160.448223},
    {'Station': "Regent's Park", 'Accessibility1.5': 158.041626},
    {'Station': 'Pimlico', 'Accessibility1.5': 156.416237},
    {'Station': 'Marylebone', 'Accessibility1.5': 148.611482},
    {'Station': 'Sloane Square', 'Accessibility1.5': 144.844463},
    {'Station': 'Paddington', 'Accessibility1.5': 143.571118},
    {'Station': 'Hyde Park Corner', 'Accessibility1.5': 139.326475},
    {'Station': 'Angel', 'Accessibility1.5': 136.925475},
    {'Station': 'Lancaster Gate', 'Accessibility1.5': 132.743893},
    {'Station': 'South Kensington', 'Accessibility1.5': 126.591671},
    {'Station': 'Edgware Road (Bakerloo)', 'Accessibility1.5': 119.771089},
    {'Station': 'Queensway', 'Accessibility1.5': 117.03565},
    {'Station': "Earl's Court", 'Accessibility1.5': 115.731822},
    {'Station': 'Notting Hill Gate', 'Accessibility1.5': 112.09225},
    {'Station': 'High Street Kensington', 'Accessibility1.5': 111.090688},
    {'Station': 'Bayswater', 'Accessibility1.5': 109.589094},
    
    {"Station": "aCannon Street", "Accessibility1.5": 222.837298},
    {"Station": "aCovent Garden", "Accessibility1.5": 200.087397},
    {"Station": "aGloucester Road", "Accessibility1.5": 181.477517},
    {"Station": "aAldgate", "Accessibility1.5": 181.012284},
    {"Station": "aMonument", "Accessibility1.5": 179.752752},
    {"Station": "aBank", "Accessibility1.5": 158.788936},
    {"Station": "aSt. Paul's", "Accessibility1.5": 157.215599},
    {"Station": "aMansion House", "Accessibility1.5": 140.388286},
    {"Station": "aEmbankment", "Accessibility1.5": 135.788555},
    {"Station": "aLeicester Square", "Accessibility1.5": 127.154896},
    {"Station": "aWarren Street", "Accessibility1.5": 125.205611},
    {"Station": "aTottenham Court Road", "Accessibility1.5": 120.987115},
    {"Station": "aLiverpool Street", "Accessibility1.5": 117.453390},
    {"Station": "aCharing Cross", "Accessibility1.5": 117.260394},
    {"Station": "aEuston Square", "Accessibility1.5": 115.456825},
    {"Station": "aPiccadilly Circus", "Accessibility1.5": 114.209254},
    {"Station": "aLambeth North", "Accessibility1.5": 102.635717},
    {"Station": "aMoorgate", "Accessibility1.5": 101.761721},
    {"Station": "aEuston", "Accessibility1.5": 100.810002},
    {"Station": "aVictoria", "Accessibility1.5": 99.975870},
    {"Station": "aAldgate East", "Accessibility1.5": 97.163868},
    {"Station": "aBarbican", "Accessibility1.5": 96.144697},
    {"Station": "aOxford Circus", "Accessibility1.5": 94.005524},
    {"Station": "aWestminster", "Accessibility1.5": 93.174337},
    {"Station": "aChancery Lane", "Accessibility1.5": 92.692683},
    {"Station": "aLondon Bridge", "Accessibility1.5": 92.254371},
    {"Station": "aFarringdon", "Accessibility1.5": 92.209691},
    {"Station": "aBlackfriars", "Accessibility1.5": 90.497882},
    {"Station": "aTower Hill", "Accessibility1.5": 89.969061},
    {"Station": "aKing's Cross St. Pancras", "Accessibility1.5": 89.043298},
    {"Station": "aTemple", "Accessibility1.5": 88.597319},                              
    {"Station": "aHolborn", "Accessibility1.5": 87.436663},
    {"Station": "aRussell Square", "Accessibility1.5": 81.908888},
    {"Station": "aTOWER GATEWAY - DLR", "Accessibility1.5": 80.822130},
    {"Station": "aGreen Park", "Accessibility1.5": 79.697347},
    {"Station": "aMarble Arch", "Accessibility1.5": 74.745920},
    {"Station": "aShoreditch High Street", "Accessibility1.5": 74.363844},
    {"Station": "aWaterloo", "Accessibility1.5": 71.106723},
    {"Station": "aBond Street", "Accessibility1.5": 71.105258},
    {"Station": "aGoodge Street", "Accessibility1.5": 69.997263},
    {"Station": "aMarylebone", "Accessibility1.5": 68.802094},
    {"Station": "aSloane Square", "Accessibility1.5": 65.161302},
    {"Station": "aSouthwark", "Accessibility1.5": 64.380786},
    {"Station": "aGreat Portland Street", "Accessibility1.5": 62.669856},
    {"Station": "aBorough", "Accessibility1.5": 60.811202},
    {"Station": "aOld Street", "Accessibility1.5": 60.454443},
    {"Station": "aSt. James's Park", "Accessibility1.5": 60.024820},
    {"Station": "aRegent's Park", "Accessibility1.5": 58.712856},
    {"Station": "aBaker Street", "Accessibility1.5": 57.187437},
    {"Station": "aPaddington", "Accessibility1.5": 57.112691},
    {"Station": "aAngel", "Accessibility1.5": 55.541363},
    {"Station": "aHyde Park Corner", "Accessibility1.5": 54.848410},
    {"Station": "aKnightsbridge", "Accessibility1.5": 51.800547},
    {"Station": "aPimlico", "Accessibility1.5": 49.126310},
    {"Station": "aSouth Kensington", "Accessibility1.5": 48.433295},
    {"Station": "aNotting Hill Gate", "Accessibility1.5": 46.352780},
    {"Station": "aEdgware Road (Bakerloo)", "Accessibility1.5": 46.246452},
    {"Station": "aLancaster Gate", "Accessibility1.5": 43.281954},
    {"Station": "aHigh Street Kensington", "Accessibility1.5": 42.917069},
    {"Station": "aQueensway", "Accessibility1.5": 40.088529},
    {"Station": "aBayswater", "Accessibility1.5": 39.800790},
    {"Station": "aEarl's Court", "Accessibility1.5": 39.350208},
    
    {"Station": "bCannon Street", "Accessibility1.5": 153.465141},
    {"Station": "bCovent Garden", "Accessibility1.5": 147.549439},
    {"Station": "bPiccadilly Circus", "Accessibility1.5": 146.858675},
    {"Station": "bLiverpool Street", "Accessibility1.5": 141.583013},
    {"Station": "bBank", "Accessibility1.5": 141.123775},
    {"Station": "bSt. Paul's", "Accessibility1.5": 130.368180},
    {"Station": "bLeicester Square", "Accessibility1.5": 127.564903},
    {"Station": "bCharing Cross", "Accessibility1.5": 119.713422},
    {"Station": "bWarren Street", "Accessibility1.5": 119.182687},
    {"Station": "bWaterloo", "Accessibility1.5": 118.390017},
    {"Station": "bEmbankment", "Accessibility1.5": 117.573305},
    {"Station": "bMansion House", "Accessibility1.5": 115.529966},
    {"Station": "bWestminster", "Accessibility1.5": 109.719966},
    {"Station": "bEuston Square", "Accessibility1.5": 109.308929},
    {"Station": "bBlackfriars", "Accessibility1.5": 99.278086},
    {"Station": "bMonument", "Accessibility1.5": 98.833685},
    {"Station": "bOxford Circus", "Accessibility1.5": 97.250717},
    {"Station": "bEuston", "Accessibility1.5": 95.950080},
    {"Station": "bAldgate", "Accessibility1.5": 89.105236},
    {"Station": "bBaker Street", "Accessibility1.5": 86.441071},
    {"Station": "bKing's Cross St. Pancras", "Accessibility1.5": 84.925455},
    {"Station": "bGreen Park", "Accessibility1.5": 83.405191},
    {"Station": "bTottenham Court Road", "Accessibility1.5": 83.162925},
    {"Station": "bAldgate East", "Accessibility1.5": 81.979843},
    {"Station": "bMoorgate", "Accessibility1.5": 80.680529},
    {"Station": "bBarbican", "Accessibility1.5": 78.220727},
    {"Station": "bVictoria", "Accessibility1.5": 77.228008},
    {"Station": "bTemple", "Accessibility1.5": 73.243115},
    {"Station": "bRussell Square", "Accessibility1.5": 71.845488},
    {"Station": "bHolborn", "Accessibility1.5": 71.284402},
    {"Station": "bMarylebone", "Accessibility1.5": 70.803311},
    {"Station": "bMarble Arch", "Accessibility1.5": 69.502020},
    {"Station": "bTower Hill", "Accessibility1.5": 68.216969},
    {"Station": "bPaddington", "Accessibility1.5": 65.504528},
    {"Station": "bGoodge Street", "Accessibility1.5": 62.767454},
    {"Station": "bLancaster Gate", "Accessibility1.5": 62.564146},
    {"Station": "bTOWER GATEWAY - DLR", "Accessibility1.5": 62.317777},
    {"Station": "bChancery Lane", "Accessibility1.5": 62.133198},
    {"Station": "bFarringdon", "Accessibility1.5": 59.798938},
    {"Station": "bSouthwark", "Accessibility1.5": 59.755560},
    {"Station": "bSt. James's Park", "Accessibility1.5": 58.976656},
    {"Station": "bBond Street", "Accessibility1.5": 58.816217},
    {"Station": "bGreat Portland Street", "Accessibility1.5": 57.389221},
    {"Station": "bShoreditch High Street", "Accessibility1.5": 56.042188},
    {"Station": "bRegent's Park", "Accessibility1.5": 53.811554},
    {"Station": "bLambeth North", "Accessibility1.5": 53.777231},
    {"Station": "bLondon Bridge", "Accessibility1.5": 53.022953},
    {"Station": "bOld Street", "Accessibility1.5": 50.408895},
    {"Station": "bQueensway", "Accessibility1.5": 49.687283},
    {"Station": "bHyde Park Corner", "Accessibility1.5": 49.485461},
    {"Station": "bEdgware Road (Bakerloo)", "Accessibility1.5": 47.883478},
    {"Station": "bKnightsbridge", "Accessibility1.5": 46.589593},
    {"Station": "bBorough", "Accessibility1.5": 45.577172},
    {"Station": "bSouth Kensington", "Accessibility1.5": 45.160253},
    {"Station": "bAngel", "Accessibility1.5": 43.575599},
    {"Station": "bBayswater", "Accessibility1.5": 43.328925},
    {"Station": "bSloane Square", "Accessibility1.5": 43.211108},
    {"Station": "bPimlico", "Accessibility1.5": 40.161405},
    {"Station": "bNotting Hill Gate", "Accessibility1.5": 37.824532},
    {"Station": "bGloucester Road", "Accessibility1.5": 36.324730},
    {"Station": "bHigh Street Kensington", "Accessibility1.5": 35.809521},
    {"Station": "bEarl's Court", "Accessibility1.5": 32.054967}
    
    
]

# 创建一个Pandas DataFrame
tube_accessibility15 = pd.DataFrame(data)

import pysal
from mapclassify import NaturalBreaks
# Choose the number of classes
num_classes = 7  # Adjust as needed

# Extract the accessibility values
accessibility_values = tube_accessibility15["Accessibility1.5"].values

# Apply Jenks' Natural Breaks algorithm
classifier = NaturalBreaks(accessibility_values, k=num_classes)  # Create an instance of the classifier
tube_accessibility15["Class"] = classifier.yb

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# Print the results
print(tube_accessibility15)
# Out:
#                        Station  Accessibility1.5  Class
# 0                      Aldgate       1482.715111      6
# 1                   St. Paul's        534.283116      5
# 2                Cannon Street        524.809292      5
# 3                         Bank        524.093095      5
# 4                     Monument        493.588015      5
# 5                 Baker Street        441.944452      5
# 6            Piccadilly Circus        431.652306      5
# 7                Mansion House        426.929167      5
# 8                Covent Garden        424.797389      5
# 9                     Barbican        406.645785      5
# 10            Liverpool Street        401.272370      5
# 11            Leicester Square        372.097670      4
# 12                 Blackfriars        361.985662      4
# 13               Oxford Circus        357.072675      4
# 14               Charing Cross        348.210559      4
# 15                    Moorgate        327.771320      4
# ...

# %%
breakpoints = classifier.bins

# 打印断点值
print("断点值：", breakpoints)
# Out:
# 断点值： [  80.82213   132.743893  191.146213  264.967224  372.09767   534.283116
#  1482.715111]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 数据
grades = ['Extremely Low', 'Very Low', 'Low', 'Moderate', 'Moderately High', 'High', 'Very High']
ranges = ['32.0-80.8', '81.9-132.7', '135.7-191.1', '199.7-264.9', '293.0-372.0', '401.2-534.2', '1482.7-']
counts = [0, 8, 17, 16, 10, 10, 1]

# 创建一个DataFrame
data = pd.DataFrame({'Grade': grades, 'Range': ranges, 'Count': counts})

# 创建一个直方图
plt.figure(figsize=(10, 6))
sns.barplot(x='Grade', y='Count', data=data, palette='viridis')

# 设置x轴标签和标题
plt.xlabel('Grade')
plt.ylabel('Count')
plt.title('Histogram')

# 显示标签和值
for index, row in data.iterrows():
    plt.text(index, row['Count'], str(row['Count']), color='black', ha="center")

# 展示图像
plt.show()
